# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Check the files 
import glob

files = glob.glob(r'C:\Users\louis\OneDrive\Desktop\PFDA\PFDA_project\weather\*.csv') 
print(files)
list_data = []
for file in files:
    data = pd.read_csv(file, skiprows=23, low_memory=False)
    list_data.append(data)

# Concatenate all data into one DataFrame
weather = pd.concat(list_data)


# Reference:
# https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe
# Out:
# ['C:\\Users\\louis\\OneDrive\\Desktop\\PFDA\\PFDA_project\\weather\\belmullet.csv', 'C:\\Users\\louis\\OneDrive\\Desktop\\PFDA\\PFDA_project\\weather\\dublinairport.csv', 'C:\\Users\\louis\\OneDrive\\Desktop\\PFDA\\PFDA_project\\weather\\johnstown.csv', 'C:\\Users\\louis\\OneDrive\\Desktop\\PFDA\\PFDA_project\\weather\\malinhead.csv', 'C:\\Users\\louis\\OneDrive\\Desktop\\PFDA\\PFDA_project\\weather\\mullingar.csv', 'C:\\Users\\louis\\OneDrive\\Desktop\\PFDA\\PFDA_project\\weather\\valentia.csv']

# %%
data
# Out:
#                      date  ind rain  ind.1 temp  ind.2 wetb dewpt vappr rhum  \
# 0       01-jan-1945 00:00    0  0.0      0  8.9      0  8.8   8.8  11.3   99
# 1       01-jan-1945 01:00    0  0.0      0  8.5      0  8.3   8.3  10.8   97
# 2       01-jan-1945 02:00    0  0.0      0  8.8      0  8.3   7.7  10.6   93
# 3       01-jan-1945 03:00    0  0.0      0  8.9      0  8.4   7.7  10.6   93
# 4       01-jan-1945 04:00    0  0.0      0  9.3      0  8.7   8.3  10.8   92
# ...                   ...  ...  ...    ...  ...    ...  ...   ...   ...  ...
# 701275  31-dec-2024 20:00    0  1.6      0  8.9      0  8.5   8.0  10.7   94
# 701276  31-dec-2024 21:00    0  3.0      0  8.6      0  8.4   8.1  10.8   96
# 701277  31-dec-2024 22:00    0  2.8      0  8.2      0  8.0   7.6  10.5   95
# 701278  31-dec-2024 23:00    0  2.6      0  8.0      0  7.5   6.9   9.9   92
# 701279  01-jan-2025 00:00    0  2.0      0  7.7      0  7.1   6.4   9.6   91
#
# ...

# %%
# list the files in the directory 

import os
print(os.listdir(r'C:\Users\louis\OneDrive\Desktop\PFDA\PFDA_project\weather'))
# Out:
# ['belmullet.csv', 'dublinairport.csv', 'johnstown.csv', 'malinhead.csv', 'mullingar.csv', 'valentia.csv']
